# %%
import os
import tensorflow as tf
# Load compressed models from tensorflow_hub
os.environ['TFHUB_MODEL_LOAD_FORMAT'] = 'COMPRESSED'

import IPython.display as display

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12, 12)
mpl.rcParams['axes.grid'] = False

import numpy as np
import PIL.Image
import time
import functools


def tensor_to_image(tensor):
  tensor = tensor*255
  tensor = np.array(tensor, dtype=np.uint8)
  if np.ndim(tensor)>3:
    assert tensor.shape[0] == 1
    tensor = tensor[0]
  return PIL.Image.fromarray(tensor)

content_path = tf.keras.utils.get_file('YellowLabradorLooking_new.jpg', 'https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg')
style_path = tf.keras.utils.get_file('kandinsky5.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg')

# %%
def load_img(path_to_img):
  max_dim = 512
  img = tf.io.read_file(path_to_img)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)

  shape = tf.cast(tf.shape(img)[:-1], tf.float32)
  long_dim = max(shape)
  scale = max_dim / long_dim

  new_shape = tf.cast(shape * scale, tf.int32)

  img = tf.image.resize(img, new_shape)
  img = img[tf.newaxis, :]
  return img


def imshow(image, title=None):
  if len(image.shape) > 3:
    image = tf.squeeze(image, axis=0)

  plt.imshow(image)
  if title:
    plt.title(title)

# %%
content_image = load_img(content_path)
style_image = load_img(style_path)

plt.subplot(1, 2, 1)
imshow(content_image, 'Content Image')

plt.subplot(1, 2, 2)
imshow(style_image, 'Style Image')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/PIL/Image.py:3080, in fromarray(obj, mode)
#    3079 try:
# -> 3080     mode, rawmode = _fromarray_typemap[typekey]
#    3081 except KeyError as e:
#
# KeyError: ((1, 1, 3), '<f4')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 11
#       7 plt.subplot(1, 2, 2)
#       8 imshow(style_image, 'Style Image')
# ---> 11 save_image(content_image, "data/dog.jpeg")
#
# Cell In[29], line 33, in save_image(image, path)
#      31 plt.figure()
#      32 plt.imshow(image.numpy())
# ---> 33 image = Image.fromarray(image.numpy())
#      34 image.save(path)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/PIL/Image.py:3083, in fromarray(obj, mode)
#    3081     except KeyError as e:
#    3082         msg = "Cannot handle this data type: %s, %s" % typekey
# -> 3083         raise TypeError(msg) from e
#    3084 else:
#    3085     rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 3), <f4

# %%
import tensorflow_hub as hub
hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]
tensor_to_image(stylized_image)
# Out:
# ---------------------------------------------------------------------------
# SSLZeroReturnError                        Traceback (most recent call last)
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/http/client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# SSLZeroReturnError: TLS/SSL connection has been closed (EOF) (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 import tensorflow_hub as hub
# ----> 2 hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
#       3 stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]
#       4 tensor_to_image(stylized_image)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/module_v2.py:92, in load(handle, tags, options)
#      90 if not isinstance(handle, str):
#      91   raise ValueError("Expected a string, got %s" % handle)
# ---> 92 module_path = resolve(handle)
#      93 is_hub_module_v1 = tf.io.gfile.exists(
#      94     native_module.get_module_proto_path(module_path))
#      95 if tags is None and is_hub_module_v1:
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/module_v2.py:47, in resolve(handle)
#      23 def resolve(handle):
#      24   """Resolves a module handle into a path.
#      25
#      26   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      45     A string representing the Module path.
#      46   """
# ---> 47   return registry.resolver(handle)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/registry.py:51, in MultiImplRegister.__call__(self, *args, **kwargs)
#      49 for impl in reversed(self._impls):
#      50   if impl.is_supported(*args, **kwargs):
# ---> 51     return impl(*args, **kwargs)
#      52   else:
#      53     fails.append(type(impl).__name__)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/compressed_module_resolver.py:67, in HttpCompressedFileResolver.__call__(self, handle)
#      63   response = self._call_urlopen(request)
#      64   return resolver.DownloadManager(handle).download_and_uncompress(
#      65       response, tmp_dir)
# ---> 67 return resolver.atomic_download(handle, download, module_dir,
#      68                                 self._lock_file_timeout_sec())
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/resolver.py:418, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     416 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     417 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 418 download_fn(handle, tmp_dir)
#     419 # Write module descriptor to capture information about which module was
#     420 # downloaded by whom and when. The file stored at the same level as a
#     421 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     426 # module caching protocol and no code in the TF-Hub library reads its
#     427 # content.
#     428 _write_module_descriptor_file(handle, module_dir)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/compressed_module_resolver.py:63, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      60 """Fetch a module via HTTP(S), handling redirect and download headers."""
#      61 request = urllib.request.Request(
#      62     self._append_compressed_format_query(handle))
# ---> 63 response = self._call_urlopen(request)
#      64 return resolver.DownloadManager(handle).download_and_uncompress(
#      65     response, tmp_dir)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/site-packages/tensorflow_hub/resolver.py:522, in HttpResolverBase._call_urlopen(self, request)
#     519 def _call_urlopen(self, request):
#     520   # Overriding this method allows setting SSL context in Python 3.
#     521   if self._context is None:
# --> 522     return urllib.request.urlopen(request)
#     523   else:
#     524     return urllib.request.urlopen(request, context=self._context)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/miniforge3/envs/tf_env/lib/python3.10/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error TLS/SSL connection has been closed (EOF) (_ssl.c:997)>

# %%
# Out:
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: protobuf>=3.8.0 in /Users/jkguo/miniforge3/envs/tf_env/lib/python3.10/site-packages (from tensorflow_hub) (3.19.4)
# Requirement already satisfied: numpy>=1.12.0 in /Users/jkguo/miniforge3/envs/tf_env/lib/python3.10/site-packages (from tensorflow_hub) (1.23.2)
# Installing collected packages: tensorflow_hub
# Successfully installed tensorflow_hub-0.12.0
